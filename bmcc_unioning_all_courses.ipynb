# %% [markdown]
# # Combining Course Information From Every Department
# * In this example I will only do the first 4 departments

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd

# %% [markdown]
# ## Combining CSV Files

# %%
df1 = pd.read_csv('accounting.csv')
df2 = pd.read_csv('academic_literacy_and_linguistics.csv')
df3 = pd.read_csv('allied_health.csv')
df4 = pd.read_csv('business_management.csv')

# %%
all_dfs = [df1, df2, df3, df4]

all_courses = pd.concat(all_dfs, ignore_index=True)
all_courses
# Out:
#        Course                                   Course Title  \
# 0     ACC 231      Accounting Applications on Microcomputers
# 1     ACC 331                 Accounting Information Systems
# 2    ACC 331H        Accounting Information Systems (Honors)
# 3     ACC 122                        Accounting Principles I
# 4     ACC 222                       Accounting Principles II
# ..        ...                                            ...
# 181   MAR 300                 Sales Principles and Practices
# 182   SBE 400                      Small Business Management
# 183   BUS 476  Social Entrepreneurship in Emerging Economics
# 184   TTA 201                              Travel Operations
# 185   HTT 301                                  World Markets
#
#            Department(s)                                        Description  \
# 0             Accounting  This course provides accounting students with ...
# 1             Accounting  The course provides accounting students with t...
# ...

# %% [markdown]
# ## Exporting

# %%
all_courses.to_csv('BMCC_Courses.csv', index=False, encoding='utf-8')
